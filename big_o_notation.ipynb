# %% [markdown]
# # Continued from matplotlib_exercises...

# %%
#5. Make a new Jupyter notebook named big_o_notation.ipynb

# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible

# Curves to graph:

#1.  y = 0x + 1 and label the curve "O(1)"
#2.  y = log(x) and label the curve "O(log n)"
#3.  y = x and label the curve "O(n)"
#4.  y = x ∗ log(x) and label it "O(n log n)"
#5.  y = x^2 and label it "O(n^2)"
#6.  y = 2^x and label it "O(2^n)"
#7.  y = n! and label it "O(n!)"
#8.  y = n^n and label it "O(n^n)"

# %%
import matplotlib.pyplot as plt

# %%
import math

# %%
plt.figure(figsize = (16,9))

# first plot
# y = 0x + 1 and label the curve "O(1)"
x1_axis=[]
y1_axis=[]
for x in range(-5, 6):  
    y = (0)*x + 1
    x1_axis.append(x)
    y1_axis.append(y)    
plt.plot(x1_axis,y1_axis, color = 'red', label = 'O(1)')

# second plot
# y = log(x) and label the curve "O(log n)"
x2_axis=[]
y2_axis=[]
for x in range(1, 6):  
    y = math.log(x)
    x2_axis.append(x)
    y2_axis.append(y)    
plt.plot(x2_axis,y2_axis, color = 'orange', label = 'O(log n)')

# third plot
# y = x and label the curve "O(n)"
x3_axis=[]
y3_axis=[]
for x in range(-5, 6):  
    y = x
    x3_axis.append(x)
    y3_axis.append(y)    
plt.plot(x3_axis,y3_axis, color = 'yellow', label = 'O(n)')

# fourth plot
# y = x ∗ log(x) and label it "O(n log n)"
x4_axis=[]
y4_axis=[]
for x in range(1, 6):  
    (x) * math.log(x)
    x4_axis.append(x)
    y4_axis.append(y)    
plt.plot(x4_axis,y4_axis, color = 'limegreen', label = 'O(n log n)')

# fifth plot
# y = x^2 and label it "O(n^2)"
x5_axis=[]
y5_axis=[]
for x in range(-1, 6):  
    y = x^2
    x5_axis.append(x)
    y5_axis.append(y)    
plt.plot(x5_axis,y5_axis, color = 'green', label = 'O(n^2)')

# sixth plot
# y = 2^x and label it "O(2^n)"
x6_axis=[]
y6_axis=[]
for x in range(-5, 1):  
    y = 2^x
    x6_axis.append(x)
    y6_axis.append(y)    
plt.plot(x6_axis,y6_axis, color = 'deepskyblue', label = 'O(2^n)')

# seventh plot
# y = n! and label it "O(n!)"
x7_axis=[]
y7_axis=[]
for n in range(0, 5):  
    y = math.factorial(n)
    x7_axis.append(x)
    y7_axis.append(y)    
plt.plot(x7_axis,y7_axis, color = 'royalblue', label = 'O(n!)')

# eighth plot
# y = n^n and label it "O(n^n)"
x8_axis=[]
y8_axis=[]
for x in range(-5, 6):  
    y = n^n
    x8_axis.append(x)
    y8_axis.append(y)    
plt.plot(x8_axis,y8_axis, color = 'purple', label = 'O(n^n)')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
#6. Bonus: Write the code necessary to write your name on a chart. Use box letters.

# %%
plt.xkcd()
plt.figure(figsize = (16,9))

plt.plot([5, 5], [20, 40], c= 'deepskyblue')
plt.plot([15, 15], [20, 40], c= 'gold')
plt.plot([5, 15], [40, 40], c= 'hotpink')
plt.plot([5, 15], [20, 20], c= 'red')

plt.plot([20, 20], [20, 40], c= 'royalblue')
plt.plot([30, 30], [20, 40], c= 'deepskyblue')
plt.plot([20, 30], [40, 40], c= 'limegreen')
plt.plot([20, 30], [30, 30], c= 'gold')

plt.plot([35, 35], [20, 40], c= 'royalblue')
plt.plot([45, 45], [20, 40], c= 'darkorange')
plt.plot([35, 45], [40, 20], c= 'hotpink')

plt.plot([55, 55], [20, 40], c= 'dodgerblue')
plt.plot([50, 60], [40, 40], c= 'red')
plt.plot([50, 60], [20, 20], c= 'limegreen')

plt.title('My Awesome Name')
plt.xlim(0, 65)
plt.ylim(0, 60)
plt.show()

# %%
#7. Bonus: Use curves for letters in your name that have curves in them.

# %%
plt.xkcd()
plt.figure(figsize = (16,9))

plt.plot([5, 5], [27, 33], c= 'red')
x_axis=[]
y_axis=[]
for y in range(27, 34):
    x= (-y**2) +60*y - 887
    x_axis.append(x)
    y_axis.append(y)
plt.plot(x_axis,y_axis, c= 'deepskyblue')

x_axis=[]
y_axis=[]
for x in range(16, 25):
    y= (-x**2) + 40*x -360
    x_axis.append(x)
    y_axis.append(y)
plt.plot(x_axis,y_axis, c= 'dodgerblue')
plt.plot([17, 23], [30, 30], c= 'gold')

plt.plot([30, 30], [25, 35], c= 'royalblue')
plt.plot([40, 40], [25, 35], c= 'darkorange')
plt.plot([30, 40], [35, 25], c= 'hotpink')

plt.plot([48, 48], [25, 35], c= 'limegreen')
plt.plot([48, 48], [38, 40], c= 'red')

plt.title('My Awesome Curvy Name')
plt.xlim(0, 53)
plt.ylim(5, 55)
plt.show()
