# %% [markdown]
# # Data Science Libraries for Python

# %% [markdown]
# - matplotlib: visualization
# - numpy: vectorized operations; arrays
# - pandas: data representation and manipulation; series and dataframes
# - seaborn: more visualization

# %% [markdown]
# # 1. Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [1,3,1]

plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
x = [1,2,3,4,5]
y = [1,3,5,15,25]

#'c' is for color
#'s' is for size of scatter plot points
#'alpha' is to adjust scatter plot point transparency


plt.plot(x, y, c = 'red')
plt.scatter(x, y, s = 50, alpha = 0.5)
plt.title('My Awesome Graph')
plt.xlabel('The x-axis')
plt.ylabel('The y-axis')
# Out:
# Text(0, 0.5, 'The y-axis')

# %%
y = [2,3,1,2,5]

plt.plot(y)
plt.xticks(range(5))
# Out:
# ([<matplotlib.axis.XTick at 0x114766d10>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
x = ['Ada', 'Bayes', 'Curie', 'Darden']
y = [17, 20, 16, 21]

plt.bar(x, y, color = 'green')
plt.yticks(range(0,26,2))
plt.title('Number of Students by Data Science Cohort')
plt.text(0, 19, 'First Cohort', ha = 'center')
plt.text(1, 22, 'Second Cohort', ha = 'center')
plt.text(2, 19, 'Third Cohort', ha = 'center')
plt.text(3, 22, 'Fourth Cohort', ha = 'center')
plt.annotate('Best Cohort', xy = (2.63, 12))
# Out:
# Text(2.63, 12, 'Best Cohort')

# %%
plt.figure(figsize = (16,9))

x = [1,2,3,4,5]
y1 = [1,1,1,3,4]
y2 = [0,2,3,3,3]
y3 = [1, -10, 5, -20, 15]

plt.plot(x,y1)
plt.plot(x,y2)

plt.plot(x,y1, label = 'Python Knowledge')
plt.plot(x,y2, label = 'SQL Knowledge')
plt.plot(x,y3, label = 'Confidence')
plt.legend()

# %%
import random

# 500 random numbers between 0 and 100
x = [random.random() * 100 for _ in range(500)]
plt.hist(x, bins = 25)
plt.title('Histogram of 500 random numbers')
# Out:
# Text(0.5, 1.0, 'Histogram of 500 random numbers')

# %%
x = [random.random()* 100 for _ in range(50)]
 
y1 = [n + random.random() * 10 for n in x]
y2 = [100 - n + random.random() * 10 for n in x]
 
plt.scatter(x, y1)
plt.scatter(x, y2)

# %%
# plt.subplot(nrows, ncols, current axis)

plt.subplot(2,1,1)
plt.scatter(x, y1)

plt.subplot(2,1,2)
plt.scatter(x, y2)

# %%
plt.subplot(1,2,1)
plt.hist(y1)
plt.title('Histogram of y1')

plt.subplot(1,2,2)
plt.scatter(x, y1)
plt.title('x vs y1')
# Out:
# Text(0.5, 1.0, 'x vs y1')

# %%
plt.figure(figsize = (15,10))

plt.subplot(2,3,1)
plt.hist(x, color = 'firebrick')
plt.title('Histogram of x')

plt.subplot(2,3,2)
plt.hist(y1, color = 'limegreen')
plt.title('Histogram of y1')

plt.subplot(2,3,3)
plt.hist(y2, color = 'rebeccapurple')
plt.title('Histogram of y2')

plt.subplot(2,3,4)
plt.plot(x, color  = 'burlywood')
plt.title('Plot of x')

plt.subplot(2,3,5)
plt.scatter(x, y1, color = 'hotpink')
plt.title('x vs y1')

plt.subplot(2,3,6)
plt.scatter(x, y2, color = 'royalblue')
plt.title('x vs y2')
# Out:
# Text(0.5, 1.0, 'x vs y2')

# %% [markdown]
# # 2. Numpy

# %%
import numpy as np

# %% [markdown]
# Vectorized Operations
# - Doing addition with every single list element requires a loop or a list comprehension

# %%
a = np.array([1,2,3,4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a + 2
# Out:
# array([3, 4, 5, 6, 7])

# %%
a - 10
# Out:
# array([-9, -8, -7, -6, -5])

# %%
a * 5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
a / 2
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5])

# %%
#Also works with boolean operators
a == 5
# Out:
# array([False, False, False, False,  True])

# %%
a > 3
# Out:
# array([False, False, False,  True,  True])

# %%
a < 3
# Out:
# array([ True,  True, False, False, False])

# %% [markdown]
# Indexing
# - Comparison operators produce boolean list or masks. These masks can be used to index into arrays to extract only the elements where the masks is true.

# %% [markdown]
# 1. Create a boolean mask
# 2. Index into the array
# 3. Negate the mask

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[0]
# Out:
# 1

# %%
a[:3]
# Out:
# array([1, 2, 3])

# %%
mask = [True, True, True, False, False]
a[mask]
# Out:
# array([1, 2, 3])

# %%
a[a < 5]
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# For comparing numpy arrays, you cannot use and/or/not
#
# Instead use:
#    - & : and
#    - | : or
#    - ~ : not

# %% [markdown]
# Methods
# - min
# - max
# - sum
# - std

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 5

# %%
a.sum()
# Out:
# 15

# %%
a.std()
# Out:
# 1.4142135623730951

# %% [markdown]
# More Examples

# %% [markdown]
# - ".all" means every single element is True
# - ".any" means at least one element is True

# %%
# Are all the elements in the list less than 10?
(a < 10).all()
# Out:
# True

# %%
# Are there any negative numbers?
(a < 0).any()
# Out:
# False

# %%
from numpy import random
random.randint(100)
# Out:
# 97

# %%
a = random.randint(100, size=(5))
a
# Out:
# array([69, 76, 34, 53, 28])

# %%
a.shape
a[a > 70].shape
# Out:
# (1,)

# %%
a.sum()
# Out:
# 260

# %%
np.random.rand(1000)
# Out:
# array([0.95099676, 0.5854072 , 0.03108118, 0.95821706, 0.10694928,
#        0.88845214, 0.18239114, 0.09141326, 0.02738667, 0.58216975,
#        0.58589503, 0.2819588 , 0.33505868, 0.20113715, 0.39058053,
#        0.2041414 , 0.52786812, 0.58310601, 0.55156339, 0.01971039,
#        0.35171084, 0.2616865 , 0.61567623, 0.53383577, 0.67805085,
#        0.50776039, 0.57113534, 0.57492636, 0.14847898, 0.83339117,
#        0.54334073, 0.26738029, 0.7531949 , 0.93437685, 0.46910529,
#        0.26853647, 0.33881961, 0.92371152, 0.32046913, 0.43405141,
#        0.24906666, 0.39937969, 0.86783167, 0.25118002, 0.66462562,
#        0.52392356, 0.81990513, 0.57263706, 0.4030634 , 0.83864557,
#        0.77217195, 0.14843245, 0.2732188 , 0.07373938, 0.73390655,
#        0.50683704, 0.35665779, 0.72301233, 0.51481314, 0.06317058,
#        0.4987508 , 0.61563827, 0.56048484, 0.94039687, 0.26865344,
#        0.41235973, 0.69637344, 0.90296179, 0.97704842, 0.76138207,
# ...

# %%
b = np.random.randint(100, size=1000)

# %%
b.shape
# Out:
# (1000,)

# %%
b.shape
b[b > 70].shape
# Out:
# (280,)

# %%
b.sum()
# Out:
# 49706

# %%
(b[(b >= 50) & (b <= 80)] ** 2).sum()
# Out:
# 1282196

# %% [markdown]
# Matrices
# - contruction
# - manipulating
# - axis

# %%
m = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# # 3. Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Series and Dataframes
#
# - Series: Imagine a single column of a table
# - Dataframes: Imagine the entire table

# %% [markdown]
# ### Create a Series
#
# 1. from a list
# 2. from a numpy array
# 3. from a dataframe

# %%
from pydataset import data

# %% [markdown]
# ### From a list

# %%
my_list = [2, 3, 5]

# create series from list
my_series = pd.Series(my_list)

# what kind of python object is it? 
print(type(my_series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# what's inside the series? 

my_series
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %% [markdown]
# ### From an array

# %%
my_array = np.array([8.0, 13.0, 21.0])

# create series from array
my_series = pd.Series(my_array)

type(my_series)
# Out:
# pandas.core.series.Series

# %%
my_series
# Out:
# 0     8.0
# 1    13.0
# 2    21.0
# dtype: float64

# %% [markdown]
# ### From a dataframe

# %%
my_df = data('titanic')

my_series = my_df.survived
print(type(my_series))

my_series = my_df['survived']
print(type(my_series))

my_not_quite_series = my_df[['survived']]
print(type(my_not_quite_series))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
my_series.head()
# Out:
# 1    yes
# 2    yes
# 3    yes
# 4    yes
# 5    yes
# Name: survived, dtype: object

# %%
my_not_quite_series.head()
# Out:
#   survived
# 1      yes
# 2      yes
# 3      yes
# 4      yes
# 5      yes

# %% [markdown]
# ## Pandas Data Types

# %% [markdown]
# Data types you will see in series and dataframes:
#
# - int: integer, whole number values
# - float: decimal numbers
# - bool: true or false values
# - object: strings
# - category: a fixed set of string values
# - a name, an optional human-friendly name for the series

# %%
#inferring

# %%
#'astype()'

# %% [markdown]
# ### Vectorized Operations

# %% [markdown]
# - Like numpy arrays, pandas series are vectorized by default. E.g., we can easily use the basic arithmetic operators to manipulate every element in the series.
# - arithmetic operations
# - comparison operations

# %% [markdown]
# ### Series Methods

# %% [markdown]
# - .any()
# - .all()
# - .head()
# - .tail()
# - .value_counts()
# - .isin()
# - Descriptive stats
